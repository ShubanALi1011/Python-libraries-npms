# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [20,50,100,50,10]
plt.plot(x,y)
plt.show()

# %%
days = ['Mon', 'Tue', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
sales = [80, 40,50,30,80,90,100]

plt.plot(days, sales)
plt.title('Sales Per Day')
plt.xlabel('Days')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# plt.plot(x, y, color = 'color name', linestyle = 'line_style', linewidth = value, marker = 'marker_symbol', label = 'label_name' )

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr']
sales = [1000, 1500, 1200, 1800]
plt.plot(months, sales, color = 'blue', linestyle = '--', linewidth = 2, marker = 'o', label = '2025 Sales Data' )
plt.title("Monthly Sales Data Report")
plt.xlabel('Months')
plt.ylabel('Sales per month')
plt.legend(loc = 'upper left', fontsize = 10 )
plt.grid(color = 'gray', linestyle = ':', linewidth = 1)
plt.xlim('Jan', 'Apr')
plt.ylim(500,2000)
plt.xticks(['Jan', 'Feb', 'Mar', 'Apr'], ['January', 'Febuary', 'March', 'Aprail'])
plt.show()

# %% [markdown]
# Bar-Chart

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr']
sales = [1000, 1500, 1200, 1800]
plt.bar(months, sales, color = 'orange', label = 'Sales 2025')
plt.ylabel("Sales Per Month")
plt.xlabel("Months")
plt.title("2025 Sales Comparison")
plt.legend()
plt.show()

# %% [markdown]
# Pie-Chart

# %% [markdown]
# plt.pie(values, labels = 'label_list', color = 'color_list', autopct = '%1.1%f')

# %%
region = ['Islamabad', 'Punjab', 'Kpk', 'Sindh', 'Baloch']
tax = [20, 30, 15, 22, 8]

plt.pie(
    tax,
    labels=region,
    autopct='%1.1f%%',
    colors=['lightgreen', 'darkgreen', 'orange', 'green', 'darkorange']
)
plt.title("Tax Contribution By Region")
plt.show()

# %% [markdown]
# Histogram

# %% [markdown]
# plt.his(data, bins = 'number_of_bins', color = 'color_name', edgecolor = 'color-name');

# %%
marks = [45,67,89,56,78,88,92,60,74,81,59,66,75,82,90,85,70,73,68,77]
plt.hist(marks, bins = 5, color='blue', edgecolor='white')
plt.xlabel('Score Range')
plt.ylabel('Number of Student')
plt.title('Score Distribution of Students')
plt.show()

# %% [markdown]
# Scatter Plot

# %% [markdown]
# plt.scatter(x, y, color='color-name', marker = 'style', labels = 'label')

# %%
hours = [1,2,3,4,5,6,7,8]
marks = [5,5.5,6,6.5,7,7.5,8,8.5]
plt.scatter(hours, marks, color = 'green', marker='o', label='Student Study Analysis')
plt.xlabel('Hours Studied')
plt.ylabel('Quiz Score')
plt.title("Relationship Between Study Time & Score")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# When Two Grpups

# %%
plt.scatter([1,2,3], [50,55,60], color = 'blue', label='Class A')
plt.scatter([1,2,3], [45,50,55], color = 'orange', label='Class B')
plt.xlabel('Hours Studied')
plt.ylabel('Quiz Score')
plt.title("Compare Two Classes")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Sub-Plot

# %% [markdown]
# plt.subplot(nrows, ncols, index)

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [10,20,15,25]

plt.subplot(1,2,1) # row 1 , 2 col, 1st subplot
plt.plot(x,y)
plt.title('Line Chart')

plt.subplot(1,2,2) # row 1 , 2 col, 2nd subplot
plt.bar(x,y);
plt.title('Bar Chart')

plt.show()

# %%
x = [1,2,3,4]
y = [10,20,15,25]

#fig, ax = plt.subplots(nrows, ncols, figsize(width, height))
fig, ax = plt.subplots(1,2, figsize = (10,5))
ax[0].plot(x,y, color = 'blue')
ax[0].set_title('Line Plot')

ax[1].bar(x,y, color = 'green')
ax[1].set_title('Bar Chart')
fig.suptitle('Comparision of Line and Bar Charts')
plt.tight_layout()
plt.show()

# %% [markdown]
# Saving Figures

# %% [markdown]
# #savefig(filename.extension, dpi = value, bbox_inches = 'tight )

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 15, 25]

plt.plot(x, y, color='blue', marker='o')

plt.title("Simple Line Plot")

plt.savefig('save.png', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# Netflix Data Aanalysis

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load data
data = pd.read_csv('netflix_titles.csv')
print(data.head())
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...
